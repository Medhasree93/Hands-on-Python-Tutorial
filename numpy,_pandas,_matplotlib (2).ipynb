# %% [markdown]
# What is Pandas?
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
#
# Why Use Pandas?
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.

# %% [markdown]
# import pandas
#
# import pandas as pd
#
# both are correct

# %% [markdown]
# What Can Pandas Do?
# Pandas gives you answers about the data. Like:
#
# Is there a correlation between two or more columns?
# What is average value?
# Max value?
# Min value?

# %% [markdown]
# What is a Series?
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# Labels
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
#
# This label can be used to access a specified value.

# %%
print (myvar[0])
# Out:
# 1

# %% [markdown]
# Create Labels
# With the index argument, you can name your own labels.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %% [markdown]
# When you have created labels, you can access an item by referring to the label.
#
# Example
# Return the value of "y":

# %%
print(myvar["y"])
# Out:
# 7

# %% [markdown]
# Task time, create your series And then label it. Show the accessing of items.

# %% [markdown]
# What is a DataFrame?
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
#
# ExampleGet your own Python Server
# Create a simple Pandas DataFrame:

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# Locate Row
# As you can see from the result above, the DataFrame is like a table with rows and columns.
#
# Pandas use the loc attribute to return one or more specified row(s)

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#use a list of indexes for multiple rows:
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
#locate column
print(df.columns[0])
# Out:
# calories

# %% [markdown]
# Named Indexes
# With the index argument, you can name your own indexes.

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
#refer to the named index:
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# df.head()

# %%
df.head()
# Out:
#       calories  duration
# day1       420        50
# day2       380        40

# %%
df.tail()
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# Data Cleaning
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# Empty cells
# Data in wrong format
# Wrong data
# Duplicates
# In this tutorial you will learn how to deal with all of them.

# %% [markdown]
# Empty Cells
#
# Empty cells can potentially give you a wrong result when you analyze data.
#
# Remove Rows
#
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows
# will not have a big impact on the result.

# %%
dirty_data = pd.read_csv("/content/sample_dirty_data.csv") #reading a csv file

# %%
dirty_data.head() #checking the data from head
# Out:
#    Student_ID    Name  Age  Gender Marks       City Enrollment_Date
# 0       101.0  Ananya   21  Female    85    Kolkata      2023-07-01
# 1       102.0   Rahul   22    Male   NaN      Delhi      2023-07-03
# 2       103.0     NaN   20  Female    78     Mumbai      2023-07-05
# 3       104.0   Arjun  NaN    Male    88  Bangalore      2023-07-07
# 4       105.0   Meera   23  Female   NaN    Chennai      2023-07-09

# %%
dirty_data.tail() #checking the data from tail
# Out:
#     Student_ID   Name  Age  Gender   Marks       City Enrollment_Date
# 8        109.0  Kavya  NaN  Female      89    Kolkata      2023-07-17
# 9        110.0   John   24    Male  absent      Delhi      2023-07-19
# 10         NaN    NaN  NaN     NaN     NaN        NaN             NaN
# 11       111.0   Ritu   23  Female      95     Mumbai      2023-07-21
# 12       112.0    NaN       Female      82  Bangalore      2023-07-23

# %% [markdown]
# Check whether there is a null value or not

# %%
dirty_data.isna()
# Out:
#     Student_ID   Name    Age  Gender  Marks   City  Enrollment_Date
# 0        False  False  False   False  False  False            False
# 1        False  False  False   False   True  False            False
# 2        False   True  False   False  False  False            False
# 3        False  False   True   False  False  False            False
# 4        False  False  False   False   True  False            False
# 5        False  False  False   False  False  False            False
# 6        False  False  False   False  False   True            False
# 7        False  False  False   False  False  False             True
# 8        False  False   True   False  False  False            False
# 9        False  False  False   False  False  False            False
# 10        True   True   True    True   True   True             True
# 11       False  False  False   False  False  False            False
# 12       False   True  False   False  False  False            False

# %% [markdown]
# check dirty_data, it is not changed, if you want to change it use, inplace = True

# %%
fill_data = dirty_data.fillna(130)
fill_data.head()
# Out:
#    Student_ID    Name  Age  Gender Marks       City Enrollment_Date
# 0       101.0  Ananya   21  Female    85    Kolkata      2023-07-01
# 1       102.0   Rahul   22    Male   130      Delhi      2023-07-03
# 2       103.0     130   20  Female    78     Mumbai      2023-07-05
# 3       104.0   Arjun  130    Male    88  Bangalore      2023-07-07
# 4       105.0   Meera   23  Female   130    Chennai      2023-07-09

# %% [markdown]
# Remove null values

# %%
new_data = dirty_data.dropna()

# %%
new_data.isnull()
# Out:
#     Student_ID   Name    Age  Gender  Marks   City  Enrollment_Date
# 0        False  False  False   False  False  False            False
# 5        False  False  False   False  False  False            False
# 9        False  False  False   False  False  False            False
# 11       False  False  False   False  False  False            False

# %% [markdown]
# print(df.duplicated()) to remove duplicates

# %% [markdown]
# We will work with datasets, slowly going into ML

# %% [markdown]
# Pandas Plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/data.csv')

df.plot()

plt.show()

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# Scatter Plot
# Specify that you want a scatter plot with the kind argument:
#
# kind = 'scatter'
#
# A scatter plot needs an x- and a y-axis.
#
# In the example below we will use "Duration" for the x-axis and "Calories" for the y-axis.
#
# Include the x and y arguments like this:
#
# x = 'Duration', y = 'Calories'

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()

# %% [markdown]
# Histogram
# Use the kind argument to specify that you want a histogram:
#
# kind = 'hist'
#
# A histogram needs only one column.
#
# A histogram shows us the frequency of each interval, e.g. how many workouts lasted between 50 and 60 minutes?
#
# In the example below we will use the "Duration" column to create the histogram:

# %%
df["Duration"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Do it yourself!!
#
# 1. Take a dataset (given by me)
#
# 2.

# %% [markdown]
# import all the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# makes plots appear inside notebook
# %matplotlib inline

# %% [markdown]
# Load the datae

# %%
df = pd.read_csv('/content/banana_quality.csv')   # upload file in Colab first
df.head()
# Out:
#        Size    Weight  Sweetness  Softness  HarvestTime  Ripeness   Acidity  \
# 0 -1.924968  0.468078   3.077832 -1.472177     0.294799  2.435570  0.271290
# 1 -2.409751  0.486870   0.346921 -2.495099    -0.892213  2.067549  0.307325
# 2 -0.357607  1.483176   1.568452 -2.645145    -0.647267  3.090643  1.427322
# 3 -0.868524  1.566201   1.889605 -1.273761    -1.006278  1.873001  0.477862
# 4  0.651825  1.319199  -0.022459 -1.209709    -1.430692  1.078345  2.812442
#
#   Quality
# 0    Good
# 1    Good
# 2    Good
# 3    Good
# 4    Good

# %%
df.tail()
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# Check information about the dataset

# %%
print("Shape:", df.shape)
print("\nColumns:\n", df.columns)

df.info()
# Out:
# Shape: (8000, 8)
#
# Columns:
#  Index(['Size', 'Weight', 'Sweetness', 'Softness', 'HarvestTime', 'Ripeness',
#        'Acidity', 'Quality'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         8000 non-null   float64
#  1   Weight       8000 non-null   float64
#  2   Sweetness    8000 non-null   float64
#  3   Softness     8000 non-null   float64
#  4   HarvestTime  8000 non-null   float64
#  5   Ripeness     8000 non-null   float64
#  6   Acidity      8000 non-null   float64
#  7   Quality      8000 non-null   object
# dtypes: float64(7), object(1)
# memory usage: 500.1+ KB

# %% [markdown]
# Statistical description of the dataset
#
# 1. Mean
# 2. Count
# 3. STD
# 4. Min/Max

# %%
df.describe()
# Out:
#               Size       Weight    Sweetness     Softness  HarvestTime  \
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000
# mean     -0.747802    -0.761019    -0.770224    -0.014441    -0.751288
# std       2.136023     2.015934     1.948455     2.065216     1.996661
# min      -7.998074    -8.283002    -6.434022    -6.959320    -7.570008
# 25%      -2.277651    -2.223574    -2.107329    -1.590458    -2.120659
# 50%      -0.897514    -0.868659    -1.020673     0.202644    -0.934192
# 75%       0.654216     0.775491     0.311048     1.547120     0.507326
# max       7.970800     5.679692     7.539374     8.241555     6.293280
#
#           Ripeness      Acidity
# count  8000.000000  8000.000000
# mean      0.781098     0.008725
# std       2.114289     2.293467
# min      -7.423155    -8.226977
# 25%      -0.574226    -1.629450
# 50%       0.964952     0.098735
# 75%       2.261650     1.682063
# max       7.249034     7.411633

# %% [markdown]
# More information: Mean, Median, Mode

# %%
print("MEAN:\n", df.mean(numeric_only=True))

print("\nMEDIAN:\n", df.median(numeric_only=True))

print("\nMODE:\n", df.mode().iloc[0])
# Out:
# MEAN:
#  Size          -0.747802
# Weight        -0.761019
# Sweetness     -0.770224
# Softness      -0.014441
# HarvestTime   -0.751288
# Ripeness       0.781098
# Acidity        0.008725
# dtype: float64
#
# MEDIAN:
#  Size          -0.897514
# Weight        -0.868659
# Sweetness     -1.020673
# Softness       0.202644
# HarvestTime   -0.934192
# Ripeness       0.964952
# Acidity        0.098735
# dtype: float64
#
# MODE:
#  Size          -7.998074
# Weight        -8.283002
# Sweetness     -6.434022
# Softness       -6.95932
# HarvestTime   -7.570008
# Ripeness      -7.423155
# Acidity       -8.226977
# Quality            Good
# Name: 0, dtype: object

# %% [markdown]
# Use of Numpy on the dataset

# %%
arr = df["Sweetness"].values

print("First 10 values:", arr[:10])
print("Mean using numpy:", np.mean(arr))
print("Std using numpy:", np.std(arr))
# Out:
# First 10 values: [ 3.0778325   0.34692144  1.5684522   1.8896049  -0.02245899  3.4476268
#   1.6811839   4.0118165   0.69874644 -0.26413944]
# Mean using numpy: -0.7702241042843923
# Std using numpy: 1.948333101180221

# %% [markdown]
# Simple Histogram (FIRST matplotlib plot)

# %%
plt.figure(figsize=(6,4))
plt.hist(df["Sweetness"], bins=30)
plt.title("Histogram of Softness")
plt.xlabel("Softness")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Boxplot: Another type of plotting

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["Weight"])
plt.title("Boxplot of Weight")
plt.show()

# %% [markdown]
# Scatter plot (relationship between features)

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["Sweetness"], df["Ripeness"], alpha=0.5)
plt.xlabel("Sweetness")
plt.ylabel("Ripeness")
plt.title("Sweetness vs Ripeness")
plt.show()

# %% [markdown]
# Count plot for Quality

# %%
df["Quality"].value_counts().plot(kind="bar")
plt.title("Quality Distribution")
plt.xlabel("Quality")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Multi-feature histograms

# %%
df.hist(figsize=(12,8))
plt.tight_layout()
plt.show()

# %% [markdown]
# Correlation heatmap

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(8,6))
plt.imshow(corr)
plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Compare Good vs Bad bananas

# %%
good = df[df["Quality"]=="Good"]["Sweetness"]
bad = df[df["Quality"]=="Bad"]["Sweetness"]

plt.hist(good, bins=30, alpha=0.5, label="Good")
plt.hist(bad, bins=30, alpha=0.5, label="Bad")

plt.legend()
plt.title("Sweetness: Good vs Bad")
plt.savefig()
plt.show()

# %%
df = pd.read_csv('/content/data-2.csv')   # upload file in Colab first
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print("Shape:", df.shape)
print("\nColumns:\n", df.columns)

df.info()
# Out:
# Shape: (569, 33)
#
# Columns:
#  Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
# ...

# %%
df= df.drop("id", axis=1)

# %%
df=df.drop("Unnamed: 32", axis=1)

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...
