# %% [markdown]
# Boolean Values
# In programming you often need to know if an expression is True or False.
#
# You can evaluate any expression in Python, and get one of two answers, True or False.
#
# When you compare two values, the expression is evaluated and Python returns the Boolean answer:

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %% [markdown]
# Evaluate Values and Variables
# The bool() function allows you to evaluate any value, and give you True or False in return,

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
x = "Hello"
y = 15

print(bool(x))
print(bool(y))
# Out:
# True
# True

# %% [markdown]
# Then which will return false?

# %%
bool(False)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool(())
# Out:
# False

# %% [markdown]
# Assignment of data in a variable to produce output

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %% [markdown]
# Python Operators
# Operators are used to perform operations on variables and values.

# %% [markdown]
# For numbers, the + character works as a mathematical operator:

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
x = 5
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1989821626.py in <cell line: 0>()
#       1 x = 5
#       2 y = "John"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# The best way to output multiple variables in the print() function is to separate them with commas, which even support different data types:

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %% [markdown]
# Question time: What will be the type of x and y?

# %% [markdown]
# Arithmatic Operations in Python

# %%
#Addition
print(5+4)
# Out:
# 9

# %%
#Addition with assignment
a= 5
b=4
print(5+4)
# Out:
# 9

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
print(a+b)
# Out:
# 95.45

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
print(a*b)
# Out:
# 452.25

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
print(a%b)
# Out:
# 0.45000000000000284

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
print(a/b)
# Out:
# 18.09

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
z = a/b
print(z)
print(type(z))
# Out:
# 18.09
# <class 'float'>

# %%
a = 5
b = 2
c = 4
d = 7
e = 1
z = a*b-b*d+d%c-d-e
print(z)
print(type(z))
# Out:
# -9
# <class 'int'>

# %%
#tryityourself

a = 3
b = 3
c = 5
d = 10
e = 15
z = a*b*c-e-d+a
print(z)
print(type(z))

# %% [markdown]
# Comparison Operator

# %%
x = 5
y = 3

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# Strings and operations

# %%
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
# Out:
# It's alright
# He is called 'Johnny'
# He is called "Johnny"

# %% [markdown]
# Slicing
# You can return a range of characters by using the slice syntax.
#
# Specify the start index and the end index, separated by a colon, to return a part of the string.

# %%
b = "Hello, World!"  #Note: The first character has index 0.
print(b[2:5])
# Out:
# llo

# %%
b = "Hello to World!"
print(b[:5]) #Slice From the Start
# Out:
# Hello

# %%
b = "Hello, World!"
print(b[2:])  #Slice To the End
# Out:
# llo, World!

# %% [markdown]
# Do it yourself: Write your full name and slice your first name!

# %%
z = "Medhasree Ghosh"
print(z[:9])
# Out:
# Medhasree

# %% [markdown]
# Do it yourself: Write your full name and slice your first name!

# %%
z = "Medhasree Ghosh"
print(z[9:])
# Out:
#  Ghosh

# %% [markdown]
# What will be the output?

# %%
x = 'Welcome'
print(x[3:5])

# %%
x = 'Welcome'
print(x[3:])

# %%
x = 'Medhasree'
print(x[2:4])

# %%
x = "I am a student of Python"
print(x[4:])

# %% [markdown]
# do the following
# 1. print student
# 2. print Python
# 3. print I
# 4. print I am a

# %% [markdown]
# Get the characters from index 2 to index 4 (llo).

# %%
txt = "Hello World"
x = txt[2:5]
print(x)

# %% [markdown]
# Modify Strings

# %% [markdown]
# upper()
# lower()
# strip()
# replace()
# split()
# count()

# %%
a = "medhasree"
print(a.upper())
# Out:
# MEDHASREE

# %%
a = "MEDHASREE"
print(a.lower())
# Out:
# medhasree

# %%
a = " Medhasree is our instructer! "
print(a)
print(a.strip()) # removes white spaces from begining and end
# Out:
#  Medhasree is our instructer!
# Medhasree is our instructer!

# %%
a = "Hi There!"
print(a.replace("H", "J")) # Replacing a character
# Out:
# Ji There!

# %%
a = "Medhasree Ghosh!"
print(a.split(" ")) # returns splitted strings where it is needed
# Out:
# ['Medhasree', 'Ghosh!']

# %%
a = "Medhasree Ghosh!"
print(a.split("G")) # returns splitted strings where it is needed
# Out:
# ['Medhasree ', 'hosh!']

# %%
a = "Medhasree Ghosh!"
print(a.split("h")) # returns splitted strings where it is needed
# Out:
# ['Med', 'asree G', 'os', '!']

# %%
a = "Medhasree"
print(a.count('e'))
# Out:
# 3

# %% [markdown]
# Do it yourself!

# %%
a = "I am learning PYTHON."
#uppercase
#lowercase
#split with m
#split with i
#Replace a with
#count the number of a in the string and print it

# %% [markdown]
# String Concatenation
# To concatenate, or combine, two strings you can use the + operator.

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
x = 'Welcome'
y = 'Coders'
print(x + y)

# %% [markdown]
# Print Join The Party

# %%
a = 'Join'
b = 'The'
c = 'Party'
z =

# %% [markdown]
# Format the string

# %% [markdown]
# As we learned in the Python Variables chapter, we cannot combine strings and numbers like this:

# %%
age = 36
#This will produce an error:
txt = "My name is John, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3301732986.py in <cell line: 0>()
#       1 age = 36
#       2 #This will produce an error:
# ----> 3 txt = "My name is John, I am " + age
#       4 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# F-Strings is now the preferred way of formatting strings.
#
# To specify a string as an f-string, simply put an f in front of the string literal, and add curly brackets {} as placeholders for variables and other operations.

# %%
age = 32
txt = f"My name is Medhasree, I am {age}"
print(txt)
# Out:
# My name is Medhasree, I am 32

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %% [markdown]
# If x = 9, what is a correct syntax to print 'The price is 9.00 dollars'?

# %%
print(f'The price is {x:.2f} dollars')

# %%
print(f'The price is {2 + 3} dollars')

# %% [markdown]
# Length of a string

# %%
a = "Medhasree"
len(a)
# Out:
# 9

# %%
a = "MedhasreeGhosh"
len(a)
# Out:
# 14

# %% [markdown]
# Try to print your name length

# %% [markdown]
# Python Collections (Arrays)
# There are four collection data types in the Python programming language:
#
# List is a collection which is ordered and changeable. Allows duplicate members.
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
# Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
# Dictionary is a collection which is ordered** and changeable. No duplicate members.

# %% [markdown]
# Python Lists and Operations

# %% [markdown]
# *   Lists are used to store multiple items in a single variable. Lists are created using square brackets:
# *   Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, and Dictionary, all with different qualities and usage.

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# List items are ordered, changeable, and allow duplicate values.
#
# List items are indexed, the first item has index [0], the second item has index [1] etc.

# %% [markdown]
# Ordered
# When we say that lists are ordered, it means that the items have a defined order, and that order will not change.
#
# If you add new items to a list, the new items will be placed at the end of the list.
#
# Note: There are some list methods that will change the order, but in general: the order of the items will not change.
#
# Changeable
# The list is changeable, meaning that we can change, add, and remove items in a list after it has been created.

# %% [markdown]
# Allow Duplicates
# Since lists are indexed, lists can have items with the same value

# %%
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
#length of list
thislist = ["apple", "banana", "cherry"]
print(len(thislist))
# Out:
# 3

# %%
#List Items - Data Types: List items can be of any data type:
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]
print(list1, list2, list3)
# Out:
# ['apple', 'banana', 'cherry'] [1, 5, 7, 9, 3] [True, False, False]

# %%
#A list can contain different data types: A list with strings, integers and boolean values:
list_x = ["abc", 34, True, 40, "male"]
print(list_x)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
print(type(list1))
# Out:
# <class 'list'>

# %% [markdown]
# List casting or construction in another way

# %%
thislist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# Access List items

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[1])
# Out:
# banana

# %%
mylist = ['sunday', 'monday', 'tuesday', 'wednesday']
print(mylist[3])
# Out:
# wednesday

# %% [markdown]
# Negative Indexing
# Negative indexing means start from the end
#
# -1 refers to the last item, -2 refers to the second last item etc.

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[-1])
# Out:
# cherry

# %% [markdown]
# Check yourself!!

# %%
mylist = ['apple', 'banana', 'banana', 'cherry']
print(mylist[2])

# %% [markdown]
# Range of Indexes
# You can specify a range of indexes by specifying where to start and where to end the range.
#
# When specifying a range, the return value will be a new list with the specified items.

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[:5])
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[:4])
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[4:])
# Out:
# ['kiwi', 'melon', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:])
# Out:
# ['cherry', 'orange', 'kiwi', 'melon', 'mango']

# %% [markdown]
# Take a list which contains 7 days of a week. Then print tuesday and wednesday.
#
# print only sunday.
#
# print monday.
#
# print the length of the list.
#
# print monday to friday.

# %% [markdown]
# Tell me quickly!

# %%
mylist = ['apple', 'banana', 'cherry']
print(mylist[-1])

# %%
mylist = ['apple', 'banana', 'cherry', 'orange', 'kiwi']
print(mylist[1:4])

# %% [markdown]
# Remove items from list

# %%
fruits = ["apple", "banana", "cherry", "banana"]
fruits.remove("banana")  # Only the first "banana" is removed
# Output: ['apple', 'cherry', 'banana']
print (fruits)
# Out:
# ['apple', 'cherry', 'banana']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist) #empty list
# Out:
# []

# %%
#what is the ouput?
list1 = ["Medhasree", "Ghosh", "32"]
list1.pop(0)

# %% [markdown]
# Do it now,
# Create a list with all 7 days in a week.
# 1. pop 3
# 2. delete first 2 days
# 3. clear the list.
# For each time print individually.

# %% [markdown]
# Change the item of a list

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %% [markdown]
# Change a Range of Item Values
# To change the value of items within a specific range, define a list with the new values, and refer to the range of index numbers where you want to insert the new values:

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %% [markdown]
# If you insert more items than you replace, the new items will be inserted where you specified, and the remaining items will move accordingly:
#
# Example
# Change the second value by replacing it with two new values:

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %% [markdown]
# Change the second and third value by replacing it with one value:

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %% [markdown]
# Add items to list

# %%
fruits = ["apple", "banana"]
fruits.append("cherry")
# Result: ['apple', 'banana', 'cherry']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# Insert Items
# To insert a new list item, without replacing any of the existing values, we can use the insert() method.
#
# The insert() method inserts an item at the specified index:

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist)

# %% [markdown]
# Try it yourself

# %%
mylist = ['apple', 'banana', 'cherry']
mylist[0] = 'kiwi'
print(mylist[0])

# %% [markdown]
# Extend a List

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %% [markdown]
# Joining of Lists

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
#Another way to join two lists is by appending all the items from list2 into list1, one by one:
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
#Use the extend() method to add list2 at the end of list1:
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# Copy List

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# take a list with (holidays)
# *   Sunday
# *   Friday
# *   Saturday
#
# Take another list with (workdays)
# *   Monday
# *   Tuesday
# *   Wednesday
# *   Thursday
#
#
# do the following:
# 1. Join these two list (holidays and workdays)
# 2. copy workdays to wokingdays
# 3. print all

# %% [markdown]
# Sort the list items

# %%
thislist = ["5", "15", "1", "3", "10", "12", "7", "2", "0"]
thislist.sort()
print(thislist)
# Out:
# ['0', '1', '10', '12', '15', '2', '3', '5', '7']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort(reverse=True)
print(thislist)
# Out:
# [100, 82, 65, 50, 23]

# %% [markdown]
# Create a list of numbers from: 10, 18, 3, 45, 12, 56,13, 64,12, 14, 16, 10, 2, ,4, 5.
#
# Sort them in both assending and descending order.

# %% [markdown]
# Reverse a list

# %%
fruits = ['apple', 'banana', 'cherry']

fruits.reverse()

# %% [markdown]
# Do it now, print your name,surname age, company name, hometown in reverse.

# %% [markdown]
# Tuples in Python

# %% [markdown]
# Tuples are used to store multiple items in a single variable.
#
# Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.
#
# A tuple is a collection which is ordered and unchangeable.
#
# Tuples are written with round brackets.

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# **Things to Remember always**
#
# Tuple Items
# Tuple items are ordered, unchangeable, and allow duplicate values.
#
# Tuple items are indexed, the first item has index [0], the second item has index [1] etc.
#
# Ordered
# When we say that tuples are ordered, it means that the items have a defined order, and that order will not change.
#
# Unchangeable
# Tuples are unchangeable, meaning that we cannot change, add or remove items after the tuple has been created.
#
# Allow Duplicates
# Since tuples are indexed, they can have items with the same value:

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %%
#length of a tuple
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %% [markdown]
# one item tuple

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
mytuple = ("apple", "banana", "cherry")
print(type(mytuple))
# Out:
# <class 'tuple'>

# %%
#can insert any datatype
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)
tuple4 = ("abc", 34, True, 40, "male")
print(tuple1)
print(tuple2)
print(tuple3)
print(tuple4)
# Out:
# ('apple', 'banana', 'cherry')
# (1, 5, 7, 9, 3)
# (True, False, False)
# ('abc', 34, True, 40, 'male')

# %%
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# **Difference between list and tuple:**
# The core difference between Python lists and tuples is mutability: lists are mutable (can be changed after creation), while tuples are immutable (cannot be changed after creation). This fundamental distinction dictates their use cases and performance characteristics.  (lists being used for dynamic collections and tuples for fixed data).

# %% [markdown]
# Access Tuple Items
# You can access tuple items by referring to the index number, inside square brackets:

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])
# Out:
# banana

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[-1])
# Out:
# cherry

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[:4])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:])
# Out:
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %% [markdown]
#  Create a tuple with 7 days of the week and access each element individually and print them.

# %% [markdown]
# count method in a list

# %%
mylist = ["apple", "banana", "apple", "cherry", "apple"]

print(mylist.count("apple"))
# Out:
# 3

# %% [markdown]
# index method in a list

# %%
mylist = ["apple", "banana", "cherry"]

print(mylist.index("banana"))
# Out:
# 1

# %% [markdown]
# Change Tuple Values
# Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.
#
# But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple.

# %%
x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %% [markdown]
# Convert into a list: Just like the workaround for changing a tuple, you can convert it into a list, add your item(s), and convert it back into a tuple.

# %%
thistuple = ("apple", "banana", "cherry")
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)

# %%
print(type(y))
# Out:
# <class 'list'>

# %%
print(type(thistuple))
# Out:
# <class 'tuple'>

# %% [markdown]
# Add tuple to a tuple. You are allowed to add tuples to tuples, so if you want to add one item, (or many), create a new tuple with the item(s), and add it to the existing tuple:

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %% [markdown]
# Unpacking a Tuple
# When we create a tuple, we normally assign values to it. This is called "packing" a tuple
#
# But, in Python, we are also allowed to extract the values back into variables. This is called "unpacking"

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# Join Two Tuples
# To join two or more tuples you can use the + operator:

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %% [markdown]
# Multiply Tuples
# If you want to multiply the content of a tuple a given number of times, you can use the * operator:

# %%
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2

print(mytuple)

# %% [markdown]
# Count method in tuple

# %%
thistuple = ("apple", "banana", "cherry", "apple", "apple")

x = thistuple.count("apple")
print(x)
# Out:
# 3

# %% [markdown]
# index method in tuple

# %%
thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

x = thistuple.index(8)

print(x)
# Out:
# 3

# %% [markdown]
# Create a Tuple
#
# Create a tuple named fruits with the following elements:
# "apple", "banana", "cherry"
#
# Print the tuple.

# %%
# Create a tuple
fruits = ("apple", "banana", "cherry")

# Print the tuple
print(fruits)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# From the fruits tuple:
#
# Print the first element
#
# Print the last element
#
# Find and print the length of the fruits tuple.

# %%
# Given tuple
fruits = ("apple", "banana", "cherry")

# Print the first element
print(fruits[0])

# Print the last element
print(fruits[-1])

# Print the length of the tuple
print(len(fruits))
# Out:
# apple
# cherry
# 3

# %% [markdown]
# Create a tuple:
#
# numbers = (1, 2, 3, 2, 4, 2)
#
# Count how many times 2 appears.

# %%
# Create the tuple
numbers = (1, 2, 3, 2, 4, 2)

# Count how many times 2 appears
count_of_two = numbers.count(2)

# Print the result
print(count_of_two)
# Out:
# 3

# %% [markdown]
# Index Method
#
# Using the same numbers tuple, find the index of 3.

# %%
# Find the index of 3
index_of_three = numbers.index(3)

# Print the result
print(index_of_three)
# Out:
# 2

# %% [markdown]
# Convert Tuple to List
#
# Convert the fruits tuple into a list and print the results and type.

# %%
# Given tuple
fruits = ("apple", "banana", "cherry")

# Convert tuple to list
fruits_list = list(fruits)

# Print the list and its type
print(fruits_list)
print(type(fruits_list))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>
