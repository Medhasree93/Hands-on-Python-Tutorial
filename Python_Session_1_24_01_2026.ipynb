# %% [markdown]
# Learning by Examples: you can edit the Python code and view the result.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Everyone print a your name after hello, like mine is "Hello, Medhasree"

# %% [markdown]
# print("Hello World!")
# print("Have a good day.")
# print("Learning Python is fun!")

# %% [markdown]
# Multiple Statements

# %%
print("Hello, I am Medhasree!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %%
print("Hello students"); print("How are you?"); print("This is the first session of python!")
# Out:
# Hello
# How are you?
# Bye bye!

# %% [markdown]
# Use of Semicolon

# %%
print("Hello") print("How are you?") print("Bye bye!")
# Out:
#   File "/tmp/ipython-input-1681240672.py", line 1
#     print("Hello") print("How are you?") print("Bye bye!")
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# Printing: Valid and Invalid

# %%
print("This will work!")
print('This will also work!')
# Out:
# This will work!
# This will also work!

# %%
#Try it yourself time
print('Hi')
print('Today we are having our first class in python basics.')
print('We learn how to print statements.')

# %%
print(5)
# Out:
# 5

# %%
print("5")
# Out:
# 5

# %%
print(This will cause an error)
# Out:
#   File "/tmp/ipython-input-2830183003.py", line 1
#     print(This will cause an error)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print("I am", 35, "years old.")
# Out:
# I am 35 years old.

# %% [markdown]
# Commenting on codes

# %%
#this is how we print
print('hi i am medhasree')
print('5 is a number') #here we are commenting
# Out:
# hi i am medhasree
# 5 is a number

# %% [markdown]
# Variables: Variables are containers for storing data values.

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %%
#Try it yourself
x = 5
y = 10
print(x, y)

# %% [markdown]
# Datatypes: See Slides

# %% [markdown]
# Printing the type

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = "Hello World"
print(type(x))
# Out:
# <class 'str'>

# %%
x = 1
y = 35656222554887711
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x = 1.10
y = 1.0
z = -35.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 1j
print(type(x))
# Out:
# <class 'complex'>

# %% [markdown]
# Casting of Variables

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
a = float(1)     # x will be 1.0
print(type(x))
print(type(y))
print(type(z))
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# Question time: What will be the result of the following code:
# print(int(35.88))??

# %% [markdown]
# Many Values to Multiple Variables

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %% [markdown]
# Question time: What will be the result of the following code:
# a, b = "5", "Medhasree"
# print(a); print(b)

# %% [markdown]
# One Value to Multiple Variables

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
#Question time: What will be the result of the following code:
x = 5
y = x
print(y)

# %% [markdown]
# Assignment of data in a variable to produce output

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %% [markdown]
# For numbers, the + character works as a mathematical operator:

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
x = 5
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1989821626.py in <cell line: 0>()
#       1 x = 5
#       2 y = "John"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# The best way to output multiple variables in the print() function is to separate them with commas, which even support different data types:

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %% [markdown]
# Question time: What will be the type of x and y?

# %% [markdown]
# Arithmatic Operations in Python

# %%
#Addition
print(5+4)
# Out:
# 9

# %%
#Addition with assignment
a= 5
b=4
print(5+4)
# Out:
# 9

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
print(a+b)

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
print(a*b)

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
print(a%b)

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
print(a/b)

# %%
#Question Time: What will be the output?
a = 90.45
b = 5
z = a/b
print(z)
print(type(z))

# %%
print("Python is easy")
print('Python is powerful')
print(Python is fun)
print("Learning Python')
